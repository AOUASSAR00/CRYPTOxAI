# %%
import requests
import pandas as pd
import json
import time
import tqdm

# %%
cmc_apikey = "69328ced-5543-43f5-80b0-7171f6f7c70d"
coinapi_apikey = "3DDA805E-5521-415B-9C67-0C08B3FECA5F"

# %%
d = {"name": "yasmine", "age": 30}
d.get('job', [])
# Out:
# []

# %%
url = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/categories"
R = requests.request("get", url, headers={
    "X-CMC_PRO_API_KEY": cmc_apikey #"sitepyheadersparameter"-<to provide APIkey
})
print("Request completed")

content = json.loads(R.content.decode("utf-8"))
cat_df = pd.DataFrame(content.get('data', []))
cat_df.to_excel("cat_df.xlsx", index=False)
cat_df
# Out:
# Request completed
#                            id                         name  \
# 0    6363a6c9cd197958bb543bf0                       Soccer
# 1    635634b93e16136f3bb2ee9e              Aptos Ecosystem
# 2    63330401558c5024ac5dade9  Internet Computer Ecosystem
# 3    63258b2a694d2a40b4040007  Farming as a Service (FaaS)
# 4    62fe5eb097edc244f4716518         Doge Chain Ecosystem
# ..                        ...                          ...
# 165  60308028d2088f200c58a005          BNB Chain Ecosystem
# 166  60291fa0db1be76c46298e83          NFTs & Collectibles
# 167  601cf8d2d8fd860e4ea5d96f           Polkadot Ecosystem
# 168  5fb62da404d1dd4c73744883                      Storage
# 169  5fb62883c9ddcc213ed13308                         DeFi
#
#                                                  title  \
# 0                                               Soccer
# 1                                      Aptos Ecosystem
# 2                          Internet Computer Ecosystem
# 3                          Farming as a Service (FaaS)
# 4                                 Doge Chain Ecosystem
# ..                                                 ...
# 165      Top BNB Chain Tokens by Market Capitalization
# 166  Top NFTs & Collectibles Tokens by Market Capit...
# 167       Top Polkadot Tokens by Market Capitalization
# 168        Top Storage Tokens by Market Capitalization
# 169           Top DeFi Tokens by Market Capitalization
#
#                                            description  num_tokens  \
# 0                                               Soccer          50
# 1                                      Aptos Ecosystem           6
# 2                          Internet Computer Ecosystem           3
# 3                          Farming as a Service (FaaS)           9
# 4                                           Doge Chain          11
# ..                                                 ...         ...
# 165  BNB Chain dual-chain architecture will empower...        2000
# 166  A NFT (non-fungible token) is a special crypto...         609
# 167  Polkadot is an open-source sharding multichain...         118
# 168  In blockchain-based decentralized cloud storag...          40
# 169  DeFi (decentralized finance) is the creation o...         569
#
#      avg_price_change    market_cap  market_cap_change        volume  \
# 0           -1.688168  1.222782e+08          -0.979357  1.735982e+07
# 1           -7.054945  4.237890e+08          -1.942880  7.701235e+07
# 2           -0.838254  1.081106e+09          -0.251900  2.768799e+07
# 3           -0.554848  0.000000e+00           0.000000  5.915406e+04
# 4           -1.301366  0.000000e+00           0.000000  7.744643e+05
# ..                ...           ...                ...           ...
# 165         65.460463  1.786201e+11           9.754189  2.415052e+10
# 166         35.638906  1.079690e+10          34.993291  8.766207e+08
# 167         -1.123090  9.863851e+09          -1.134544  5.938188e+08
# 168          1.276564  2.852130e+09           1.049587  2.274975e+08
# 169         -1.087572  3.598847e+10          -1.025701  1.851599e+09
#
#      volume_change              last_updated
# 0        91.385333  2022-11-03T11:36:20.885Z
# 1       180.178720  2022-10-24T06:46:17.004Z
# 2       118.709700  2022-09-27T14:09:39.579Z
# 3        99.633556  2022-09-17T08:55:03.546Z
# 4        -5.774855  2022-08-22T04:40:45.482Z
# ..             ...                       ...
# 165    1762.924631  2022-02-28T09:24:12.374Z
# 166     326.579122  2021-05-04T10:36:15.891Z
# 167      36.895232  2021-03-23T08:38:28.669Z
# 168      28.611184  2021-03-23T08:38:28.660Z
# 169     135.017115  2021-03-23T08:38:28.630Z
#
# [170 rows x 11 columns]

# %%
category_id = '635634b93e16136f3bb2ee9e'
def get_coin_data(category_id):
    url = f"https://pro-api.coinmarketcap.com/v1/cryptocurrency/category?id={category_id}&aux=volume_7d,volume_30d"
    R = requests.request("get", url, headers={
        "X-CMC_PRO_API_KEY": cmc_apikey #"sitepyheadersparameter"-<to provide APIkey
    })
#     print("Request completed")

    content = json.loads(R.content.decode("utf-8"))
    content = content.get('data', {}) #Return empty dict if 'data' is not found in keys
    content = content.get('coins', []) #Return empty dict if 'coins' is not found in keys
    cat_data = pd.DataFrame(content)
    cat_data['category_id'] = category_id
    
    return cat_data

# %%
coin_df = []
for x in tqdm.tqdm(cat_df['id'].unique()):
    coin_df.append(get_coin_data(x))
    time.sleep(2)

coin_df = pd.concat(coin_df)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 170/170 [06:52<00:00,  2.43s/it]

# %%
#coin_df.to_csv
coin_df.to_excel("coin_df.xlsx", index=False)

# %%
cat_df.sample()
# Out:
#                           id                 name                title  \
# 14  620a2bac3ee27777ad05bdaa  Injective Ecosystem  Injective Ecosystem
#
#             description  num_tokens  avg_price_change    market_cap  \
# 14  Injective Ecosystem         125         -3.442399  2.383546e+11
#
#     market_cap_change        volume  volume_change              last_updated
# 14          -3.017305  2.615889e+10      32.894713  2022-02-14T10:15:43.933Z

# %%
coin_df.sample()
# Out:
#        id               name symbol               slug  num_market_pairs  \
# 86  11805  Structure finance    STF  structure-finance                 4
#
#                   date_added  \
# 86  2021-09-10T18:23:36.000Z
#
#                                                  tags   max_supply  \
# 86  [asset-management, defi, derivatives, chromia-...  100000000.0
#
#     circulating_supply  total_supply  \
# 86                 0.0   100000000.0
#
#                                              platform  is_active  cmc_rank  \
# 86  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...          1    4610.0
#
#     is_fiat self_reported_circulating_supply self_reported_market_cap  \
# 86        0                       14211829.0             74852.501735
#
#    tvl_ratio              last_updated  \
# 86       NaN  2022-12-28T13:24:00.000Z
#
#                                                 quote  \
# 86  {'USD': {'price': 0.005266915450168035, 'volum...
#
#                  category_id
# 86  6051a80266fc1b42617d6d98

# %%
cat_coin_df = cat_df.merge(right=coin_df, left_on="id", right_on="category_id",suffixes=('_category','_coin'))
cat_coin_df.sample()
# Out:
#                    id_category                     name_category  \
# 6012  604f2735ebccdd50cd175faa  Centralized Exchange (CEX) Token
#
#                                  title                       description  \
# 6012  Centralized Exchange (CEX) Token  Centralized Exchange (CEX) Token
#
#       num_tokens  avg_price_change    market_cap  market_cap_change  \
# 6012          80         242.52855  9.147349e+09         242.473304
#
#             volume  volume_change  ...  \
# 6012  1.315695e+08      67.216315  ...
#
#                                                platform  is_active cmc_rank  \
# 6012  {'id': 1839, 'name': 'BNB', 'symbol': 'BNB', '...          1   5306.0
#
#      is_fiat self_reported_circulating_supply  self_reported_market_cap  \
# 6012       0                        9749863.0              40972.103527
#
#      tvl_ratio         last_updated_coin  \
# 6012      None  2022-12-28T13:26:00.000Z
#
#                                                   quote  \
# 6012  {'USD': {'price': 0.004202326076451849, 'volum...
#
#                    category_id
# 6012  604f2735ebccdd50cd175faa
#
# [1 rows x 31 columns]

# %%
with open('cat_coin_df.json', 'w', encoding='utf8') as f:
    json.dump(cat_coin_df.to_dict('r'), f)
# Out:
# C:\Users\Zouheir\AppData\Local\Temp\ipykernel_16280\438895814.py:2: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   json.dump(cat_coin_df.to_dict('r'), f)

# %%
cat_coin_df[cat_coin_df['name_coin'] == "XRP"].T
# Out:
#                                                                                2039  \
# id_category                                                605e2e38d41eae1066535f7f
# name_category                                             Pantera Capital Portfolio
# title                                                     Pantera Capital Portfolio
# description                                               Pantera Capital Portfolio
# num_tokens                                                                       53
# avg_price_change                                                          -3.775613
# market_cap                                                      500852998129.329956
# market_cap_change                                                           -3.5552
# volume                                                            22914577591.17622
# volume_change                                                             17.648112
# last_updated_category                                      2021-03-26T23:24:51.227Z
# id_coin                                                                          52
# name_coin                                                                       XRP
# symbol                                                                          XRP
# slug                                                                            xrp
# num_market_pairs                                                                870
# date_added                                                 2013-08-04T00:00:00.000Z
# tags                              [medium-of-exchange, enterprise-solutions, arr...
# max_supply                                                           100000000000.0
# circulating_supply                                                    50343500506.0
# total_supply                                                          99989184828.0
# platform                                                                       None
# is_active                                                                         1
# cmc_rank                                                                        6.0
# is_fiat                                                                           0
# self_reported_circulating_supply                                                NaN
# self_reported_market_cap                                                        NaN
# tvl_ratio                                                                       NaN
# last_updated_coin                                          2022-12-28T13:21:00.000Z
# quote                             {'USD': {'price': 0.35840149032971197, 'volume...
# category_id                                                605e2e38d41eae1066535f7f
#
#                                                                                2128  \
# id_category                                                605e2ce9d41eae1066535f7c
# name_category                                                        a16z Portfolio
# title                                                                a16z Portfolio
# description                                                          a16z Portfolio
# num_tokens                                                                       19
# avg_price_change                                                          -2.802133
# market_cap                                                      493405238724.459961
# market_cap_change                                                         -2.802889
# volume                                                            22299644502.85379
# volume_change                                                             22.167374
# last_updated_category                                      2021-11-10T17:23:01.089Z
# id_coin                                                                          52
# name_coin                                                                       XRP
# symbol                                                                          XRP
# slug                                                                            xrp
# num_market_pairs                                                                870
# date_added                                                 2013-08-04T00:00:00.000Z
# tags                              [medium-of-exchange, enterprise-solutions, arr...
# max_supply                                                           100000000000.0
# circulating_supply                                                    50343500506.0
# total_supply                                                          99989184828.0
# platform                                                                       None
# is_active                                                                         1
# cmc_rank                                                                        6.0
# is_fiat                                                                           0
# self_reported_circulating_supply                                                NaN
# self_reported_market_cap                                                        NaN
# tvl_ratio                                                                       NaN
# last_updated_coin                                          2022-12-28T13:22:00.000Z
# quote                             {'USD': {'price': 0.3585730160335955, 'volume_...
# category_id                                                605e2ce9d41eae1066535f7c
#
#                                                                                2449
# id_category                                                605bc602972c9053da7021a9
# name_category                                       Arrington XRP Capital Portfolio
# title                                               Arrington XRP Capital Portfolio
# description                                         Arrington XRP Capital Portfolio
# num_tokens                                                                       37
# avg_price_change                                                          -3.182584
# market_cap                                                       11282895441.940001
# market_cap_change                                                         -2.920563
# volume                                                             672007448.368965
# volume_change                                                              20.08638
# last_updated_category                                      2021-11-10T16:56:14.614Z
# id_coin                                                                          52
# name_coin                                                                       XRP
# symbol                                                                          XRP
# slug                                                                            xrp
# num_market_pairs                                                                870
# date_added                                                 2013-08-04T00:00:00.000Z
# tags                              [medium-of-exchange, enterprise-solutions, arr...
# max_supply                                                           100000000000.0
# circulating_supply                                                    50343500506.0
# total_supply                                                          99989184828.0
# platform                                                                       None
# is_active                                                                         1
# cmc_rank                                                                        6.0
# is_fiat                                                                           0
# self_reported_circulating_supply                                                NaN
# self_reported_market_cap                                                        NaN
# tvl_ratio                                                                       NaN
# last_updated_coin                                          2022-12-28T13:22:00.000Z
# quote                             {'USD': {'price': 0.3585730160335955, 'volume_...
# category_id                                                605bc602972c9053da7021a9

# %%
# symbol = "BTC"
def get_time_series(symbol):
#     symbol = symbol.upper()
    url = f"https://rest.coinapi.io/v1/exchangerate/{symbol}/USD/history?period_id=1HRS&limit=200&time_start=2022-12-21T00:00:00&time_end=2022-12-28T00:00:00"
    R = requests.request("get", url, headers={
        "X-CoinAPI-Key": coinapi_apikey #"sitepyheadersparameter"-<to provide APIkey
    })
    print("Request completed: ", R.status_code)
    if R.status_code != 200:
        return R.content
    
    
    content = json.loads(R.content.decode("utf-8"))
    ts_df = pd.DataFrame(content)
    ts_df['symbol'] = symbol
    return ts_df

# %%
get_time_series("ETH")
# Out:
# Request completed:  429
# b'{\n  "error": "Too many requests - You have exceeded your API key last 24 hour requests executed limit, please wait for new requests or contact support for upgrading your existing plan or enabling overage.",\n  "faq_0": "Q: How requests are calculated? A: The request is a single API call to our REST API without \\u0060limit\\u0060 parameter. Or with \\u0060limit\\u0060 parameter, the request is counted every 100 data points returned by the API.",\n  "faq_1": "Q: How I can monitor number of requests left? A: Every authenticated API call providing information about the current state of the limits in the HTTP response headers, more info here: https://docs.coinapi.io/#request-limits",\n  "faq_2": "Q: I\\u0027m on Professional plan. How I can have more requests? A: Please contact support at the https://www.coinapi.io/support for more information.",\n  "faq_3": "Q: I\\u0027m on free plan and I didn\\u0027t executed 100 requests yet and got 429 error. A: Free plan contains additional limitations to prevent fraud and usage of the multiple free API keys to obey the limits."\n}'

# %%
# symbol = "BTC"
def get_metadata(symbol):
#     symbol = symbol.upper()
    url = f"https://pro-api.coinmarketcap.com/v2/cryptocurrency/info?symbol={symbol}"
    R = requests.request("get", url, headers={
        "X-CMC_PRO_API_KEY": cmc_apikey #"sitepyheadersparameter"-<to provide APIkey
    })
    print("Request completed: ", R.status_code)
    if R.status_code != 200:
        return R.content
    
    
    content = json.loads(R.content.decode("utf-8"))
    meta_df = pd.DataFrame(content['data'][symbol])
    return meta_df

# %%
M = get_metadata("ETH")
M = M.set_index('symbol')
# Out:
# Request completed:  200

# %%
M
# Out:
#           id      name category  \
# symbol
# ETH     1027  Ethereum     coin
#
#                                               description      slug  \
# symbol
# ETH     Ethereum (ETH) is a cryptocurrency . Ethereum ...  ethereum
#
#                                                      logo subreddit notice  \
# symbol
# ETH     https://s2.coinmarketcap.com/static/img/coins/...  ethereum
#
#                                                      tags  \
# symbol
# ETH     [pos, smart-contracts, ethereum-ecosystem, coi...
#
#                                                 tag-names  ...  \
# symbol                                                     ...
# ETH     [PoS, Smart Contracts, Ethereum Ecosystem, Coi...  ...
#
#                                                      urls platform  \
# symbol
# ETH     {'website': ['https://www.ethereum.org/', 'htt...     None
#
#                       date_added twitter_username is_hidden  date_launched  \
# symbol
# ETH     2015-08-07T00:00:00.000Z         ethereum         0           None
#
#                                          contract_address  \
# symbol
# ETH     [{'contract_address': '0x2170ed0880ac9a755fd29...
#
#        self_reported_circulating_supply self_reported_tags  \
# symbol
# ETH                                None               None
#
#        self_reported_market_cap
# symbol
# ETH                        None
#
# [1 rows x 21 columns]

# %%
(M['urls'].values[0])
#This must become its own dataframe
# Out:
# {'website': ['https://www.ethereum.org/',
#   'https://en.wikipedia.org/wiki/Ethereum'],
#  'twitter': ['https://twitter.com/ethereum'],
#  'message_board': ['https://forum.ethereum.org/', 'https://ethresear.ch/'],
#  'chat': ['https://gitter.im/orgs/ethereum/rooms'],
#  'facebook': [],
#  'explorer': ['https://etherscan.io/',
#   'https://ethplorer.io/',
#   'https://blockchair.com/ethereum',
#   'https://bscscan.com/token/0x2170ed0880ac9a755fd29b2688956bd959f933f8'],
#  'reddit': ['https://reddit.com/r/ethereum'],
#  'technical_doc': ['https://github.com/ethereum/wiki/wiki/White-Paper'],
#  'source_code': ['https://github.com/ethereum/go-ethereum'],
#  'announcement': ['https://bitcointalk.org/index.php?topic=428589.0']}
