# %%
import requests
import pandas as pd
import json

# %%
url = "https://rest.coinapi.io/v1/exchanges?limit=1000"
apikey = "3DDA805E-5521-415B-9C67-0C08B3FECA5F"

# %%
R = requests.request("get", url, headers={
    "X-CoinAPI-Key": apikey
})

content = json.loads(R.content.decode("utf-8"))

# %%
pd.DataFrame(content)
# Out:
#     exchange_id                    website                 name  data_start  \
# 0       BINANCE   https://www.binance.com/              Binance  2017-07-14
# 1        KRAKEN    https://www.kraken.com/               Kraken  2013-10-22
# 2      COINBASE  https://pro.coinbase.com/  Coinbase Pro (GDAX)  2015-01-14
# 3      BITSTAMP  https://www.bitstamp.net/        Bitstamp Ltd.  2011-09-13
# 4        GEMINI        https://gemini.com/               Gemini  2015-10-08
# ..          ...                        ...                  ...         ...
# 332     INDODAX       https://indodax.com/              Indodax  2019-04-05
# 333        BITZ     https://www.bit-z.com/                Bit-Z  2018-03-25
# 334      COINEX    https://www.coinex.com/               CoinEx  2019-10-01
# 335       WEXNZ            https://wex.nz/                WexNz  2017-12-22
# 336         AAX       https://www.aax.com/                  AAX  2020-04-24
#
# ...
